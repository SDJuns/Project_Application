# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/프로젝트응용(신동준, 이재훈, 최민규)/data/모델용데이터/train_v1.csv')
df.shape
# Out:
# (34728, 16)

# %%
df.head()
# Out:
#    AGE_GRP GENDER  TRAVEL_MONTH  TRAVEL_PERIOD  NTvsCT  EXPLODvsCHPLOD  \
# 0     60.0      여            10              3       2               1
# 1     60.0      여            10              3       2               1
# 2     60.0      여            10              3       2               1
# 3     60.0      여            10              3       2               1
# 4     60.0      여            10              3       2               1
#
#    RESTvsACT  UNKvsK MVMN_NM TRAVEL_MISSION_CHECK1 TRAVEL_MISSION_CHECK2  \
# 0          2       2  대중교통 등              종교/성지 순례             역사 유적지 방문
# 1          2       2  대중교통 등              종교/성지 순례             역사 유적지 방문
# 2          2       2  대중교통 등              종교/성지 순례             역사 유적지 방문
# 3          2       2  대중교통 등              종교/성지 순례             역사 유적지 방문
# 4          2       2  대중교통 등              종교/성지 순례             역사 유적지 방문
#
#   TRAVEL_MOTIVE_1         TRAVEL_MOTIVE_2     budget  VISIT_AREA_NM  DGSTFN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34728 entries, 0 to 34727
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AGE_GRP                34728 non-null  float64
#  1   GENDER                 34728 non-null  object
#  2   TRAVEL_MONTH           34728 non-null  int64
#  3   TRAVEL_PERIOD          34728 non-null  int64
#  4   NTvsCT                 34728 non-null  int64
#  5   EXPLODvsCHPLOD         34728 non-null  int64
#  6   RESTvsACT              34728 non-null  int64
#  7   UNKvsK                 34728 non-null  int64
#  8   MVMN_NM                34728 non-null  object
#  9   TRAVEL_MISSION_CHECK1  34728 non-null  object
#  10  TRAVEL_MISSION_CHECK2  34728 non-null  object
#  11  TRAVEL_MOTIVE_1        34728 non-null  object
#  12  TRAVEL_MOTIVE_2        34728 non-null  object
#  13  budget                 34728 non-null  float64
# ...

# %%
df_ad = pd.read_csv('/content/drive/MyDrive/프로젝트응용(신동준, 이재훈, 최민규)/data/전처리/주소 통합(4).csv')
df_ad.shape
# Out:
# (30862, 25)

# %%
df_ad.columns
# Out:
# Index(['AGE_GRP', 'GENDER', 'TRAVEL_MONTH', 'TRAVEL_PERIOD', 'NTvsCT',
#        'EXPLODvsCHPLOD', 'RESTvsACT', 'UNKvsK', 'MVMN_NM',
#        'TRAVEL_MISSION_CHECK1', 'TRAVEL_MISSION_CHECK2', 'TRAVEL_MOTIVE_1',
#        'TRAVEL_MOTIVE_2', 'TRAVEL_MOTIVE_3', 'budget', 'VISIT_AREA_NM',
#        'DGSTFN', 'ROAD_NM_ADDR', 'LOTNO_ADDR', 'X_COORD', 'Y_COORD', 'address',
#        'LONGEST_ADDR', 'INTEGRATED_REGION', 'INTEGRATED_CITY'],
#       dtype='object')

# %%
df_ad = df_ad.drop(columns=['TRAVEL_MOTIVE_3', 'ROAD_NM_ADDR', 'LOTNO_ADDR', 'X_COORD', 'Y_COORD', 'address'])

# %%
df_ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30862 entries, 0 to 30861
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AGE_GRP                30862 non-null  float64
#  1   GENDER                 30862 non-null  object
#  2   TRAVEL_MONTH           30862 non-null  int64
#  3   TRAVEL_PERIOD          30862 non-null  int64
#  4   NTvsCT                 30862 non-null  int64
#  5   EXPLODvsCHPLOD         30862 non-null  int64
#  6   RESTvsACT              30862 non-null  int64
#  7   UNKvsK                 30862 non-null  int64
#  8   MVMN_NM                30862 non-null  object
#  9   TRAVEL_MISSION_CHECK1  30862 non-null  int64
#  10  TRAVEL_MISSION_CHECK2  30862 non-null  int64
#  11  TRAVEL_MOTIVE_1        30862 non-null  float64
#  12  TRAVEL_MOTIVE_2        30862 non-null  float64
#  13  budget                 30862 non-null  float64
# ...

# %%
df_ad.loc[(df_ad['INTEGRATED_REGION'].isin(['서울특별시', '대전광역시', '대구광역시', '울산광역시', '부산광역시', '세종특별자치시', '광주광역시', '인천광역시'])) & (df_ad['INTEGRATED_CITY'].notnull())]
# Out:
#        AGE_GRP GENDER  TRAVEL_MONTH  TRAVEL_PERIOD  NTvsCT  EXPLODvsCHPLOD  \
# 31        30.0      여            10              1       1               2
# 32        30.0      여            10              1       1               2
# 34        30.0      여            10              1       1               2
# 199       40.0      여            10              1       1               2
# 209       20.0      여            10              1       1               1
# 406       20.0      남            10              2       1               1
# 701       20.0      남            10              1       1               1
# 877       20.0      남            10              2       3               1
# 1334      40.0      남            10              2       1               1
# 1498      40.0      여            10              1       3               1
# 1669      20.0      남            10              2       2               2
# ...

# %%
# 마지막으로 조금 덜 조정된 것들 수정 조금 +
df_ad.loc[df_ad['LONGEST_ADDR'].str.startswith('경기'), 'INTEGRATED_REGION'] = '경기도'
df_ad.loc[df_ad['LONGEST_ADDR'].str.startswith('제주'), 'INTEGRATED_REGION'] = '제주특별자치도'
df_ad.loc[df_ad['LONGEST_ADDR'].str.startswith('경북'), 'INTEGRATED_REGION'] = '경상북도'
df_ad.loc[df_ad['LONGEST_ADDR'].str.startswith('전북'), 'INTEGRATED_REGION'] = '전북특별자치도'

# %%
df_ad.loc[(df_ad['INTEGRATED_REGION'].isin(['서울특별시', '대전광역시', '대구광역시', '울산광역시', '부산광역시', '세종특별자치시', '광주광역시', '인천광역시'])) & (df_ad['INTEGRATED_CITY'].notnull())]
# Out:
#        AGE_GRP GENDER  TRAVEL_MONTH  TRAVEL_PERIOD  NTvsCT  EXPLODvsCHPLOD  \
# 199       40.0      여            10              1       1               2
# 1669      20.0      남            10              2       2               2
# 2520      30.0      여            10              1       3               2
# 2521      30.0      여            10              1       3               2
# 13707     30.0      여            10              3       1               1
#
#        RESTvsACT  UNKvsK MVMN_NM  TRAVEL_MISSION_CHECK1  \
# 199            1       1  대중교통 등                      1
# 1669           3       2  대중교통 등                      3
# 2520           3       1  대중교통 등                      1
# 2521           3       1  대중교통 등                      1
# 13707          2       1  대중교통 등                     23
#
#        TRAVEL_MISSION_CHECK2  TRAVEL_MOTIVE_1  TRAVEL_MOTIVE_2    budget  \
# 199                        6              1.0              4.0   50500.0
# ...

# %%
# 마지막으로 조금 덜 조정된 것들 수정 조금 +
df_ad.loc[df_ad['LONGEST_ADDR'].str.startswith('경기'), 'INTEGRATED_REGION'] = '경기도'
df_ad.loc[df_ad['LONGEST_ADDR'].str.startswith('제주'), 'INTEGRATED_REGION'] = '제주특별자치도'
df_ad.loc[df_ad['LONGEST_ADDR'].str.startswith('경북'), 'INTEGRATED_REGION'] = '경상북도'
df_ad.loc[df_ad['LONGEST_ADDR'].str.startswith('전북'), 'INTEGRATED_REGION'] = '전북특별자치도'

# 이건 더 안된 것들. 아예 제거가 나을 듯.
# 조건을 만족하는 행의 인덱스를 제거하는 코드
df_ad = df_ad.drop(df_ad.loc[(df_ad['INTEGRATED_REGION'].isin(['서울특별시', '인천광역시'])) & (df_ad['INTEGRATED_CITY'].notna())].index)

df_ad['INTEGRATED_CITY'] = df_ad['INTEGRATED_CITY'].fillna('미선택')

df_ad['AGE_GRP'] = df_ad['AGE_GRP'].astype(int)

df_ad = df_ad[['INTEGRATED_REGION', 'INTEGRATED_CITY', 'AGE_GRP', 'GENDER', 'TRAVEL_MONTH', 'TRAVEL_PERIOD', 'NTvsCT', 'EXPLODvsCHPLOD', 'RESTvsACT', 'UNKvsK',
             'MVMN_NM', 'TRAVEL_MISSION_CHECK1', 'TRAVEL_MISSION_CHECK2', 'TRAVEL_MOTIVE_1', 'TRAVEL_MOTIVE_2', 'budget',
             'VISIT_AREA_NM', 'DGSTFN', 'LONGEST_ADDR']]

# %%
# df_ad.to_csv('/content/drive/MyDrive/프로젝트응용(신동준, 이재훈, 최민규)/data/전처리/train_add_last.csv', index=False)

# %%
df_ad.shape
# Out:
# (30857, 19)

# %%
df_merge_add = pd.merge(df, df_ad, on='VISIT_AREA_NM', how='right')
df_merge_add.shape
# Out:
# (218766, 34)

# %% [markdown]
# # 불러오기

# %%
df_train = pd.read_csv('/content/drive/MyDrive/프로젝트응용(신동준, 이재훈, 최민규)/data/전처리/train_v2(결측_이상).csv')
df_test = pd.read_csv('/content/drive/MyDrive/프로젝트응용(신동준, 이재훈, 최민규)/data/전처리/test_v2(결측_이상).csv')
df_train.shape, df_test.shape
# Out:
# ((32333, 21), (1656, 21))

# %% [markdown]
# ## TRAVEL_MISSION_CHECK1, 2 숫자 밀기

# %%
df_cd = pd.read_csv('/content/drive/MyDrive/프로젝트응용(신동준, 이재훈, 최민규)/data/압축해제/train/tc_codeb_코드B.csv')

# %%
df_cd.loc[df_cd['cd_a'] == 'MIS']
# Out:
#       idx                 cd_nm cd_a cd_b cd_memo  cd_memo2 del_flag  \
# 105  1097                    쇼핑  MIS    1     NaN       NaN        N
# 106  1098  테마파크, 놀이시설, 동/식물원 방문  MIS    2     NaN       NaN        N
# 107  1099             역사 유적지 방문  MIS    3     NaN       NaN        N
# 108  1100                  시티투어  MIS    4     NaN       NaN        N
# 109  1101        야외 스포츠, 레포츠 활동  MIS    5     NaN       NaN        N
# 110  1102    지역 문화예술/공연/전시시설 관람  MIS    6     NaN       NaN        N
# 111  1103         유흥/오락(나이트라이프)  MIS    7     NaN       NaN        N
# 112  1104                    캠핑  MIS    8     NaN       NaN        N
# 113  1105          지역 축제/이벤트 참가  MIS    9     NaN       NaN        N
# 114  1106                 온천/스파  MIS   10     NaN       NaN        N
# 115  1107         교육/체험 프로그램 참가  MIS   11     NaN       NaN        N
# 116  1108            드라마 촬영지 방문  MIS   12     NaN       NaN        N
# 117  1109              종교/성지 순례  MIS   13     NaN       NaN        N
# ...

# %% [markdown]
# # 변환 딕셔너리

# %%
# TRAVEL_MISSION_CHECK1, TRAVEL_MISSION_CHECK2에 대한 변환 딕셔너리
mission_check_labels = {
    1: "쇼핑",
    2: "테마파크, 놀이시설, 동/식물원 방문",
    3: "역사 유적지 방문",
    4: "시티투어",
    5: "야외 스포츠, 레포츠 활동",
    6: "지역 문화예술/공연/전시시설 관람",
    7: "유흥/오락(나이트라이프)",
    8: "캠핑",
    9: "지역 축제/이벤트 참가",
    10: "온천/스파",
    11: "교육/체험 프로그램 참가",
    12: "드라마 촬영지 방문",
    13: "종교/성지 순례",
    21: "Well-ness 여행",
    22: "SNS 인생샷 여행",
    23: "호캉스 여행",
    24: "신규 여행지 발굴",
    25: "반려동물 동반 여행",
    26: "인플루언서 따라하기 여행",
    27: "친환경 여행(플로깅 여행)",
    28: "등반 여행"
}

# TRAVEL_MOTIVE_1, TRAVEL_MOTIVE_2, TRAVEL_MOTIVE_3에 대한 변환 딕셔너리
motive_labels = {
    1.0: "일상적인 환경 및 역할에서의 탈출, 지루함 탈피",
    2.0: "쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식",
    3.0: "여행 동반자와의 친밀감 및 유대감 증진",
    4.0: "진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기",
    5.0: "SNS 사진 등록 등 과시",
    6.0: "운동, 건강 증진 및 충전",
    7.0: "새로운 경험 추구",
    8.0: "역사 탐방, 문화적 경험 등 교육적 동기"
}

# TRAVEL_MISSION_CHECK1, TRAVEL_MISSION_CHECK2 열의 값 변경
for column in ['TRAVEL_MISSION_CHECK1', 'TRAVEL_MISSION_CHECK2']:
    df_train[column] = df_train[column].map(mission_check_labels).fillna(df_train[column])

# TRAVEL_MOTIVE_1, TRAVEL_MOTIVE_2, TRAVEL_MOTIVE_3 열의 값 변경
for column in ['TRAVEL_MOTIVE_1', 'TRAVEL_MOTIVE_2', 'TRAVEL_MOTIVE_3']:
    df_train[column] = df_train[column].map(motive_labels).fillna(df_train[column])

df_train.loc[df_train['NTvsCT'] == 1, 'NTvsCT'] = "자연 선호"
df_train.loc[df_train['NTvsCT'] == 2, 'NTvsCT'] = "상관 없음"
df_train.loc[df_train['NTvsCT'] == 3, 'NTvsCT'] = "도시 선호"
df_train.loc[df_train['EXPLODvsCHPLOD'] == 1, 'EXPLODvsCHPLOD'] = "비싼숙소 선호"
df_train.loc[df_train['EXPLODvsCHPLOD'] == 2, 'EXPLODvsCHPLOD'] = "상관 없음"
df_train.loc[df_train['EXPLODvsCHPLOD'] == 3, 'EXPLODvsCHPLOD'] = "저렴한숙소 선호"
df_train.loc[df_train['RESTvsACT'] == 1, 'RESTvsACT'] = "휴식 선호"
df_train.loc[df_train['RESTvsACT'] == 2, 'RESTvsACT'] = "상관 없음"
df_train.loc[df_train['RESTvsACT'] == 3, 'RESTvsACT'] = "활동 선호"
df_train.loc[df_train['UNKvsK'] == 1, 'UNKvsK'] = "알려지지 않은 장소 선호"
df_train.loc[df_train['UNKvsK'] == 2, 'UNKvsK'] = "상관 없음"
df_train.loc[df_train['UNKvsK'] == 3, 'UNKvsK'] = "알려진장소 선호"

# %%
df_train['TRAVEL_MOTIVE_3'].unique()
# Out:
# array(['쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식', 'SNS 사진 등록 등 과시',
#        '일상적인 환경 및 역할에서의 탈출, 지루함 탈피', '진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기',
#        '새로운 경험 추구', '운동, 건강 증진 및 충전', '역사 탐방, 문화적 경험 등 교육적 동기'],
#       dtype=object)

# %%
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 1, 'TRAVEL_MISSION_CHECK1'] = "쇼핑"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 2, 'TRAVEL_MISSION_CHECK1'] = "테마파크, 놀이시설, 동/식물원 방문"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 3, 'TRAVEL_MISSION_CHECK1'] = "역사 유적지 방문"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 4, 'TRAVEL_MISSION_CHECK1'] = "시티투어"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 5, 'TRAVEL_MISSION_CHECK1'] = "야외 스포츠, 레포츠 활동"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 6, 'TRAVEL_MISSION_CHECK1'] = "지역 문화예술/공연/전시시설 관람"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 7, 'TRAVEL_MISSION_CHECK1'] = "유흥/오락(나이트라이프)"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 8, 'TRAVEL_MISSION_CHECK1'] = "캠핑"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 9, 'TRAVEL_MISSION_CHECK1'] = "지역 축제/이벤트 참가"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 10, 'TRAVEL_MISSION_CHECK1'] = "온천/스파"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 11, 'TRAVEL_MISSION_CHECK1'] = "교육/체험 프로그램 참가"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 12, 'TRAVEL_MISSION_CHECK1'] = "드라마 촬영지 방문"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 13, 'TRAVEL_MISSION_CHECK1'] = "종교/성지 순례"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 21, 'TRAVEL_MISSION_CHECK1'] = "Well-ness 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 22, 'TRAVEL_MISSION_CHECK1'] = "SNS 인생샷 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 23, 'TRAVEL_MISSION_CHECK1'] = "호캉스 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 24, 'TRAVEL_MISSION_CHECK1'] = "신규 여행지 발굴"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 25, 'TRAVEL_MISSION_CHECK1'] = "반려동물 동반 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 26, 'TRAVEL_MISSION_CHECK1'] = "인플루언서 따라하기 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 27, 'TRAVEL_MISSION_CHECK1'] = "친환경 여행(플로깅 여행)"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK1'] == 28, 'TRAVEL_MISSION_CHECK1'] = "등반 여행"

# %%
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 1, 'TRAVEL_MISSION_CHECK2'] = "쇼핑"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 2, 'TRAVEL_MISSION_CHECK2'] = "테마파크, 놀이시설, 동/식물원 방문"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 3, 'TRAVEL_MISSION_CHECK2'] = "역사 유적지 방문"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 4, 'TRAVEL_MISSION_CHECK2'] = "시티투어"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 5, 'TRAVEL_MISSION_CHECK2'] = "야외 스포츠, 레포츠 활동"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 6, 'TRAVEL_MISSION_CHECK2'] = "지역 문화예술/공연/전시시설 관람"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 7, 'TRAVEL_MISSION_CHECK2'] = "유흥/오락(나이트라이프)"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 8, 'TRAVEL_MISSION_CHECK2'] = "캠핑"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 9, 'TRAVEL_MISSION_CHECK2'] = "지역 축제/이벤트 참가"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 10, 'TRAVEL_MISSION_CHECK2'] = "온천/스파"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 11, 'TRAVEL_MISSION_CHECK2'] = "교육/체험 프로그램 참가"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 12, 'TRAVEL_MISSION_CHECK2'] = "드라마 촬영지 방문"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 13, 'TRAVEL_MISSION_CHECK2'] = "종교/성지 순례"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 21, 'TRAVEL_MISSION_CHECK2'] = "Well-ness 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 22, 'TRAVEL_MISSION_CHECK2'] = "SNS 인생샷 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 23, 'TRAVEL_MISSION_CHECK2'] = "호캉스 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 24, 'TRAVEL_MISSION_CHECK2'] = "신규 여행지 발굴"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 25, 'TRAVEL_MISSION_CHECK2'] = "반려동물 동반 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 26, 'TRAVEL_MISSION_CHECK2'] = "인플루언서 따라하기 여행"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 27, 'TRAVEL_MISSION_CHECK2'] = "친환경 여행(플로깅 여행)"
# df_train.loc[df_train['TRAVEL_MISSION_CHECK2'] == 28, 'TRAVEL_MISSION_CHECK2'] = "등반 여행"

# %%
df_train['TRAVEL_MISSION_CHECK1'].unique()
# Out:
# array(['종교/성지 순례', '쇼핑', '테마파크, 놀이시설, 동/식물원 방문', '교육/체험 프로그램 참가',
#        'Well-ness 여행', '지역 축제/이벤트 참가', '시티투어', '등반 여행', '역사 유적지 방문',
#        '지역 문화예술/공연/전시시설 관람', '친환경 여행(플로깅 여행)', 'SNS 인생샷 여행', '호캉스 여행',
#        '야외 스포츠, 레포츠 활동', '인플루언서 따라하기 여행', '신규 여행지 발굴', '캠핑', '반려동물 동반 여행',
#        '온천/스파', '유흥/오락(나이트라이프)', '드라마 촬영지 방문'], dtype=object)

# %%
df_train['TRAVEL_MISSION_CHECK2'].unique()
# Out:
# array(['역사 유적지 방문', 'SNS 인생샷 여행', '지역 문화예술/공연/전시시설 관람', '인플루언서 따라하기 여행',
#        '쇼핑', '등반 여행', '신규 여행지 발굴', '친환경 여행(플로깅 여행)', '시티투어', '반려동물 동반 여행',
#        '테마파크, 놀이시설, 동/식물원 방문', '드라마 촬영지 방문', 'Well-ness 여행', '종교/성지 순례',
#        '교육/체험 프로그램 참가', '지역 축제/이벤트 참가', '호캉스 여행', '온천/스파',
#        '유흥/오락(나이트라이프)', '야외 스포츠, 레포츠 활동', '캠핑'], dtype=object)

# %%
# # TRAVEL_MOTIVE_1
# df_train.loc[df_train['TRAVEL_MOTIVE_1'] == 1.0, 'TRAVEL_MOTIVE_1'] = "일상적인 환경 및 역할에서의 탈출, 지루함 탈피"
# df_train.loc[df_train['TRAVEL_MOTIVE_1'] == 2.0, 'TRAVEL_MOTIVE_1'] = "쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식"
# df_train.loc[df_train['TRAVEL_MOTIVE_1'] == 3.0, 'TRAVEL_MOTIVE_1'] = "여행 동반자와의 친밀감 및 유대감 증진"
# df_train.loc[df_train['TRAVEL_MOTIVE_1'] == 4.0, 'TRAVEL_MOTIVE_1'] = "진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기"
# df_train.loc[df_train['TRAVEL_MOTIVE_1'] == 5.0, 'TRAVEL_MOTIVE_1'] = "SNS 사진 등록 등 과시"
# df_train.loc[df_train['TRAVEL_MOTIVE_1'] == 6.0, 'TRAVEL_MOTIVE_1'] = "운동, 건강 증진 및 충전"
# df_train.loc[df_train['TRAVEL_MOTIVE_1'] == 7.0, 'TRAVEL_MOTIVE_1'] = "새로운 경험 추구"
# df_train.loc[df_train['TRAVEL_MOTIVE_1'] == 8.0, 'TRAVEL_MOTIVE_1'] = "역사 탐방, 문화적 경험 등 교육적 동기"
# # TRAVEL_MOTIVE_2
# df_train.loc[df_train['TRAVEL_MOTIVE_2'] == 1.0, 'TRAVEL_MOTIVE_2'] = "일상적인 환경 및 역할에서의 탈출, 지루함 탈피"
# df_train.loc[df_train['TRAVEL_MOTIVE_2'] == 2.0, 'TRAVEL_MOTIVE_2'] = "쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식"
# df_train.loc[df_train['TRAVEL_MOTIVE_2'] == 3.0, 'TRAVEL_MOTIVE_2'] = "여행 동반자와의 친밀감 및 유대감 증진"
# df_train.loc[df_train['TRAVEL_MOTIVE_2'] == 4.0, 'TRAVEL_MOTIVE_2'] = "진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기"
# df_train.loc[df_train['TRAVEL_MOTIVE_2'] == 5.0, 'TRAVEL_MOTIVE_2'] = "SNS 사진 등록 등 과시"
# df_train.loc[df_train['TRAVEL_MOTIVE_2'] == 6.0, 'TRAVEL_MOTIVE_2'] = "운동, 건강 증진 및 충전"
# df_train.loc[df_train['TRAVEL_MOTIVE_2'] == 7.0, 'TRAVEL_MOTIVE_2'] = "새로운 경험 추구"
# df_train.loc[df_train['TRAVEL_MOTIVE_2'] == 8.0, 'TRAVEL_MOTIVE_2'] = "역사 탐방, 문화적 경험 등 교육적 동기"
# # TRAVEL_MOTIVE_3
# df_train.loc[df_train['TRAVEL_MOTIVE_3'] == 1.0, 'TRAVEL_MOTIVE_3'] = "일상적인 환경 및 역할에서의 탈출, 지루함 탈피"
# df_train.loc[df_train['TRAVEL_MOTIVE_3'] == 2.0, 'TRAVEL_MOTIVE_3'] = "쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식"
# df_train.loc[df_train['TRAVEL_MOTIVE_3'] == 3.0, 'TRAVEL_MOTIVE_3'] = "여행 동반자와의 친밀감 및 유대감 증진"
# df_train.loc[df_train['TRAVEL_MOTIVE_3'] == 4.0, 'TRAVEL_MOTIVE_3'] = "진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기"
# df_train.loc[df_train['TRAVEL_MOTIVE_3'] == 5.0, 'TRAVEL_MOTIVE_3'] = "SNS 사진 등록 등 과시"
# df_train.loc[df_train['TRAVEL_MOTIVE_3'] == 6.0, 'TRAVEL_MOTIVE_3'] = "운동, 건강 증진 및 충전"
# df_train.loc[df_train['TRAVEL_MOTIVE_3'] == 7.0, 'TRAVEL_MOTIVE_3'] = "새로운 경험 추구"
# df_train.loc[df_train['TRAVEL_MOTIVE_3'] == 8.0, 'TRAVEL_MOTIVE_3'] = "역사 탐방, 문화적 경험 등 교육적 동기"

# %%
df_train['TRAVEL_MOTIVE_1'].unique()
# Out:
# array(['새로운 경험 추구', '일상적인 환경 및 역할에서의 탈출, 지루함 탈피', 'SNS 사진 등록 등 과시',
#        '쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식', '운동, 건강 증진 및 충전',
#        '역사 탐방, 문화적 경험 등 교육적 동기', '진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기'],
#       dtype=object)

# %%
df_train['TRAVEL_MOTIVE_2'].unique()
# Out:
# array(['역사 탐방, 문화적 경험 등 교육적 동기', 'SNS 사진 등록 등 과시',
#        '일상적인 환경 및 역할에서의 탈출, 지루함 탈피', '새로운 경험 추구',
#        '쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식', '운동, 건강 증진 및 충전',
#        '진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기'], dtype=object)

# %%
df_train['TRAVEL_MOTIVE_3'].unique()
# Out:
# array(['쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식', 'SNS 사진 등록 등 과시',
#        '일상적인 환경 및 역할에서의 탈출, 지루함 탈피', '진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기',
#        '새로운 경험 추구', '운동, 건강 증진 및 충전', '역사 탐방, 문화적 경험 등 교육적 동기'],
#       dtype=object)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32333 entries, 0 to 32332
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AGE_GRP                32333 non-null  float64
#  1   GENDER                 32333 non-null  object
#  2   TRAVEL_MONTH           32333 non-null  int64
#  3   TRAVEL_PERIOD          32333 non-null  int64
#  4   NTvsCT                 32333 non-null  object
#  5   EXPLODvsCHPLOD         32333 non-null  object
#  6   RESTvsACT              32333 non-null  object
#  7   UNKvsK                 32333 non-null  object
#  8   MVMN_NM                32333 non-null  object
#  9   TRAVEL_MISSION_CHECK1  32333 non-null  object
#  10  TRAVEL_MISSION_CHECK2  32333 non-null  object
#  11  TRAVEL_MOTIVE_1        32333 non-null  object
#  12  TRAVEL_MOTIVE_2        32333 non-null  object
#  13  TRAVEL_MOTIVE_3        32333 non-null  object
# ...

# %%
df_train.loc[df_train['NTvsCT'] == 1, 'NTvsCT'] = "자연 선호"
df_train.loc[df_train['NTvsCT'] == 2, 'NTvsCT'] = "상관 없음"
df_train.loc[df_train['NTvsCT'] == 3, 'NTvsCT'] = "도시 선호"
df_train.loc[df_train['EXPLODvsCHPLOD'] == 1, 'EXPLODvsCHPLOD'] = "비싼숙소 선호"
df_train.loc[df_train['EXPLODvsCHPLOD'] == 2, 'EXPLODvsCHPLOD'] = "상관 없음"
df_train.loc[df_train['EXPLODvsCHPLOD'] == 3, 'EXPLODvsCHPLOD'] = "저렴한숙소 선호"
df_train.loc[df_train['RESTvsACT'] == 1, 'RESTvsACT'] = "휴식 선호"
df_train.loc[df_train['RESTvsACT'] == 2, 'RESTvsACT'] = "상관 없음"
df_train.loc[df_train['RESTvsACT'] == 3, 'RESTvsACT'] = "활동 선호"
df_train.loc[df_train['UNKvsK'] == 1, 'UNKvsK'] = "알려지지 않은 장소 선호"
df_train.loc[df_train['UNKvsK'] == 2, 'UNKvsK'] = "상관 없음"
df_train.loc[df_train['UNKvsK'] == 3, 'UNKvsK'] = "알려진장소 선호"

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32333 entries, 0 to 32332
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AGE_GRP                32333 non-null  float64
#  1   GENDER                 32333 non-null  object
#  2   TRAVEL_MONTH           32333 non-null  int64
#  3   TRAVEL_PERIOD          32333 non-null  int64
#  4   NTvsCT                 32333 non-null  object
#  5   EXPLODvsCHPLOD         32333 non-null  object
#  6   RESTvsACT              32333 non-null  object
#  7   UNKvsK                 32333 non-null  object
#  8   MVMN_NM                32333 non-null  object
#  9   TRAVEL_MISSION_CHECK1  32333 non-null  object
#  10  TRAVEL_MISSION_CHECK2  32333 non-null  object
#  11  TRAVEL_MOTIVE_1        32333 non-null  object
#  12  TRAVEL_MOTIVE_2        32333 non-null  object
#  13  TRAVEL_MOTIVE_3        32333 non-null  object
# ...

# %%
df_train
# Out:
#        AGE_GRP GENDER  TRAVEL_MONTH  TRAVEL_PERIOD NTvsCT EXPLODvsCHPLOD  \
# 0         60.0      여            10              3  상관 없음        비싼숙소 선호
# 1         60.0      여            10              3  상관 없음        비싼숙소 선호
# 2         60.0      여            10              3  상관 없음        비싼숙소 선호
# 3         60.0      여            10              3  상관 없음        비싼숙소 선호
# 4         60.0      여            10              3  상관 없음        비싼숙소 선호
# ...        ...    ...           ...            ...    ...            ...
# 32328     20.0      여             9              1  자연 선호        비싼숙소 선호
# 32329     50.0      여             9              1  상관 없음        비싼숙소 선호
# 32330     50.0      여             9              1  상관 없음        비싼숙소 선호
# 32331     50.0      여             9              1  상관 없음        비싼숙소 선호
# 32332     50.0      여             9              1  상관 없음        비싼숙소 선호
#
#       RESTvsACT         UNKvsK MVMN_NM TRAVEL_MISSION_CHECK1  ...  \
# ...

# %%
dd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-06f342d4bc0b> in <cell line: 1>()
# ----> 1 dd
#
# NameError: name 'dd' is not defined

# %% [markdown]
# # 데이터 정규분포형태 만들어보기

# %%
from scipy.stats import boxcox

# Box-Cox 변환 (데이터에 0 이상의 값만 존재해야 함)
budget_transformed, _ = boxcox(df['budget'] + 1)  # 만약 값이 0일 경우 +1을 해줘야 함
df['budget'] = budget_transformed

# df_train['DGSTFN_transformed2'] = np.sqrt(df_train['DGSTFN'])

# %%
# # 히스토그램 시각화
# plt.figure(figsize=(12, 6))

# # Box-Cox 변환 히스토그램 (DGSTFN_transformed1)
# plt.subplot(1, 2, 1)
# sns.histplot(df_train['DGSTFN_transformed1'], bins=30, kde=True)
# plt.title('Histogram of Box-Cox Transformed DGSTFN (Transformed1)')
# plt.xlabel('DGSTFN_transformed1')

# # 제곱근 변환 히스토그램 (DGSTFN_transformed2)
# plt.subplot(1, 2, 2)
# sns.histplot(df_train['DGSTFN_transformed2'], bins=30, kde=True)
# plt.title('Histogram of Square Root Transformed DGSTFN (Transformed2)')
# plt.xlabel('DGSTFN_transformed2')

# plt.tight_layout()
# plt.show()

# %%
# from sklearn.utils import resample

# # 1~3 구간과 4~5 구간으로 데이터 분리
# low_satisfaction = df_train[df_train['DGSTFN'] <= 4]
# high_satisfaction = df_train[df_train['DGSTFN'] > 4]

# # 1~3 구간 데이터 업샘플링
# low_satisfaction_upsampled = resample(low_satisfaction,
#                                       replace=True,
#                                       n_samples=len(high_satisfaction),  # 4~5 구간과 균형 맞추기
#                                       random_state=42)

# # 업샘플링 후 데이터 재결합
# df_balanced = pd.concat([low_satisfaction_upsampled, high_satisfaction])

# # 만족도 히스토그램 시각화
# plt.figure(figsize=(8, 6))
# sns.histplot(df_balanced['DGSTFN'], bins=5, kde=True)
# plt.title("Histogram of Balanced DGSTFN after Upsampling")
# plt.xlabel("DGSTFN")
# plt.ylabel("Frequency")
# plt.show()

# %%
1656/32333

# %%
df_train.info()

# %%
# from sklearn.preprocessing import LabelEncoder

# # 데이터프레임을 df로 가정
# label_encoder = LabelEncoder()

# # object 타입의 칼럼만 선택하여 레이블 인코딩 수행
# for col in df_train.select_dtypes(include=['object']).columns:
#     df_train[col] = label_encoder.fit_transform(df_train[col])

# for col in df_test.select_dtypes(include=['object']).columns:
#     df_test[col] = label_encoder.fit_transform(df_test[col])

# %%
df_train.drop(columns=['ROAD_NM_ADDR', 'LOTNO_ADDR', 'X_COORD', 'Y_COORD'], inplace=True)
df_test.drop(columns=['ROAD_NM_ADDR', 'LOTNO_ADDR', 'X_COORD', 'Y_COORD'], inplace=True)

# %% [markdown]
# # RandomForest

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import mean_squared_error, r2_score

# # 훈련 및 테스트 데이터 설정
# X_train = df_train.drop(columns=['DGSTFN'])  # 타겟 변수를 제외한 특성 데이터 (훈련)
# y_train = df_train['DGSTFN']  # 타겟 변수 (훈련)

# X_test = df_test.drop(columns=['DGSTFN'])  # 타겟 변수를 제외한 특성 데이터 (테스트)
# y_test = df_test['DGSTFN']  # 타겟 변수 (테스트)

# # Random Forest Regressor 모델 초기화 및 학습
# model = RandomForestRegressor(n_estimators=10000, max_depth=25, random_state=42)
# model.fit(X_train, y_train)

# # 예측 수행
# y_pred = model.predict(X_test)

# # 성능 평가
# mse = mean_squared_error(y_test, y_pred)
# r2 = r2_score(y_test, y_pred)

# print("Mean Squared Error (MSE):", mse)
# print("R-squared (R2):", r2)

# %% [markdown]
# # Catboost - 1

# %%
pip install catboost

# %%
# from catboost import CatBoostRegressor
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# # 특성 데이터와 타겟 변수 설정
# X_train = df_train.drop(columns=['DGSTFN'])  # 타겟 변수를 제외한 훈련 데이터
# y_train = df_train['DGSTFN']  # 훈련 데이터의 타겟 변수

# X_test = df_test.drop(columns=['DGSTFN'])  # 타겟 변수를 제외한 테스트 데이터
# y_test = df_test['DGSTFN']  # 테스트 데이터의 타겟 변수

# # 범주형 특성 지정 (예시)
# cat_features = ['GENDER', 'MVMN_NM', 'VISIT_AREA_NM']  # 범주형 변수가 있는 경우 해당 열 이름을 지정

# # CatBoostRegressor 모델 초기화
# model = CatBoostRegressor(iterations=2000,
#                           learning_rate=0.01,
#                           depth=10,
#                           cat_features=cat_features,  # 범주형 변수 설정
#                           random_seed=42,
#                           verbose=100)

# # 모델 학습
# model.fit(X_train, y_train)

# # 예측 수행
# y_train_pred = model.predict(X_train)
# y_test_pred = model.predict(X_test)

# # MAE, MSE, RMSE 계산
# train_mae = mean_absolute_error(y_train, y_train_pred)
# test_mae = mean_absolute_error(y_test, y_test_pred)

# train_mse = mean_squared_error(y_train, y_train_pred)
# test_mse = mean_squared_error(y_test, y_test_pred)

# train_rmse = np.sqrt(train_mse)
# test_rmse = np.sqrt(test_mse)

# # Adjusted R-squared 계산 함수
# def adjusted_r2(y_true, y_pred, X):
#     r2 = r2_score(y_true, y_pred)
#     n = X.shape[0]  # 샘플 수
#     p = X.shape[1]  # 특성 수
#     return 1 - (1 - r2) * (n - 1) / (n - p - 1)

# # R-squared 및 Adjusted R-squared 계산
# train_r2 = r2_score(y_train, y_train_pred)
# test_r2 = r2_score(y_test, y_test_pred)

# train_adj_r2 = adjusted_r2(y_train, y_train_pred, X_train)
# test_adj_r2 = adjusted_r2(y_test, y_test_pred, X_test)

# # 결과 출력
# results = {
#     "Train Data": {
#         "MAE": train_mae,
#         "MSE": train_mse,
#         "RMSE": train_rmse,
#         "R-squared": train_r2,
#         "Adjusted R-squared": train_adj_r2,
#     },
#     "Test Data": {
#         "MAE": test_mae,
#         "MSE": test_mse,
#         "RMSE": test_rmse,
#         "R-squared": test_r2,
#         "Adjusted R-squared": test_adj_r2,
#     }
# }

# print(results)

# %% [markdown]
# # Catboost - 2

# %%
df_train.info()

# %%
categorical_features_names = [
    'GENDER', 'MVMN_NM', 'TRAVEL_MOTIVE_1', 'TRAVEL_MOTIVE_2', 'TRAVEL_MOTIVE_3', 'VISIT_AREA_NM'
]
df_train[categorical_features_names[2:-1]] = df_train[categorical_features_names[2:-1]].astype(int)
df_train.shape

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(df_train, test_size = 0.2, random_state=42)

train_df.shape, val_df.shape

# %%
from catboost import CatBoostRegressor, Pool

train_pool = Pool(train_df.drop(['DGSTFN'], axis=1),
                  label = train_df['DGSTFN'],
                  cat_features = categorical_features_names)

val_pool = Pool(val_df.drop(['DGSTFN'], axis=1),
                 label = val_df['DGSTFN'],
                 cat_features = categorical_features_names)

# %%
model = CatBoostRegressor(
    loss_function = 'RMSE',
    eval_metric='MAE',
    task_type='GPU',
    depth=10,
    learning_rate=0.01,
    n_estimators=5000
)
model.fit(
    train_pool,
    eval_set = val_pool,
    verbose=500,
    plot=True
)

# %% [markdown]
# # 데이터 합쳐보기
